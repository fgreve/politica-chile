# %%
#extraer datos web
import urllib
import urllib.request
from bs4 import BeautifulSoup

# %%
def make_soup(url):
    thepage = urllib.request.urlopen(url)
    soupdata = BeautifulSoup(thepage, "html.parser")
    return soupdata

# %%
url = "https://www.camara.cl/diputados/diputados.aspx#mostrarDiputados"

# %%
soup = make_soup(url)

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="es-CL" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <!-- inicio metatags-->
# <title>Honorable Cámara de Diputadas y Diputados - Chile</title>
# <meta content="index, follow" name="robots"/>
# <meta charset="utf-8"/>
# <meta content="Sitio oficial de la Honorable Cámara de Diputados de Chile, organismo encargado por la Constitución Política de la elaboración de las leyes en conjunto con el Gobierno y el Senado" name="description"/>
# <!-- utiles -->
# <link href="https://www.camara.cl/" rel="canonical"/>
# <meta content="noodp,noydir" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!-- Meta tags Twitter-->
# <meta content="summary" property="twitter:card"/>
# ...

# %%
tabla=soup.find_all('div')

# %%
print(tabla)
# Out:
# [<div class="auxi">
# <h1 class="aleft" id="logo">
# <a href="/index.aspx" target="_top">
# <img alt="Volver a la Portada del sitio" height="73" src="/img/logo_blanco2.png" width="73"/></a>
# <span><span>CÁMARA DE</span>DIPUTADAS Y DIPUTADOS</span>
# </h1>
# <!--Inicio Botón Responsive-->
# <div class="ui-state-default ui-corner-all responsiveBtn" id="button">
# <div class="colBtn">
# <div class="con" id="button2">
# <div class="bar top"></div>
# <div class="bar middle"></div>
# <div class="bar bottom"></div>
# </div>
# </div>
# </div>
# <script>
#                 $(function () {
#                     $("#button").click(function () {
#                         $("#effect").toggleClass("show", 1000);
#                     });
#                 });
#             </script>
# <script>
#                 $(function () {
#                     $("#button").click(function () {
#                         $("#button2").toggleClass("open", 1000);
#                     });
#                 });
# ...

# %%
tabla_senadores = soup.find("div", {"id": "ContentPlaceHolder1_ContentPlaceHolder1_pnlDiputadosLista"})

# %%
print(tabla_senadores)
# Out:
# <div id="ContentPlaceHolder1_ContentPlaceHolder1_pnlDiputadosLista">
# <article class="grid-2">
# <a href="detalle/mociones.aspx?prmID=1008">
# <img alt="Sr. Florcita Alarcón" height="100" src="/img.aspx?prmID=GRCL1008" title="Sr. Florcita Alarcón" width="100"/></a>
# <h4><a href="detalle/mociones.aspx?prmID=1008">Sr. Florcita Alarcón</a></h4>
# <p>Distrito: N°17</p>
# <p>Partido: PH</p>
# <a class="contacto" href="mailto:florcita.alarcon@congreso.cl?subject=Consulta"><i class="fa fa-envelope-o"></i>Contactar</a>
# <div class="separa"></div>
# </article>
# <article class="grid-2">
# <a href="detalle/mociones.aspx?prmID=1009">
# <img alt="Sr. Jorge Alessandri" height="100" src="/img.aspx?prmID=GRCL1009" title="Sr. Jorge Alessandri" width="100"/></a>
# <h4><a href="detalle/mociones.aspx?prmID=1009">Sr. Jorge Alessandri</a></h4>
# <p>Distrito: N°10</p>
# <p>Partido: UDI</p>
# ...

# %%
lista = tabla_senadores.find_all('article')

# %%
lista[10]
# Out:
# <article class="grid-2">
# <a href="detalle/mociones.aspx?prmID=1012">
# <img alt="Sr. Boris Barrera" height="100" src="/img.aspx?prmID=GRCL1012" title="Sr. Boris Barrera" width="100"/></a>
# <h4><a href="detalle/mociones.aspx?prmID=1012">Sr. Boris Barrera</a></h4>
# <p>Distrito: N°9</p>
# <p>Partido: PC</p>
# <a class="contacto" href="mailto:boris.barrera@congreso.cl?subject=Consulta"><i class="fa fa-envelope-o"></i>Contactar</a>
# <div class="separa"></div>
# </article>

# %%
lista[10].find('img')
# Out:
# <img alt="Sr. Boris Barrera" height="100" src="/img.aspx?prmID=GRCL1012" title="Sr. Boris Barrera" width="100"/>

# %%
lista[10].find('img').get('title')
# Out:
# 'Sr. Boris Barrera'

# %%
lista[0].find_all('p')[1].text
# Out:
# 'Partido: PH'

# %%
senadores = []
partidos = []

for persona in lista:
    senadores.append(persona.find('img').get('title'))
    partidos.append(persona.find_all('p')[1].text)

# %%
senadores
# Out:
# ['Sr. Florcita Alarcón',
#  'Sr. Jorge Alessandri',
#  'Sr. René Alinco',
#  'Sr. Sebastián Álvarez',
#  'Sra. Jenny Álvarez',
#  'Sr. Pedro Pablo Alvarez-Salamanca',
#  'Sra. Sandra Amar',
#  'Sr. Gabriel Ascencio',
#  'Sr. Pepe Auth',
#  'Sr. Nino Baltolu',
#  'Sr. Boris Barrera',
#  'Sr. Ramón Barros',
#  'Sr. Jaime Bellolio',
#  'Sr. Bernardo Berger',
#  'Sr. Alejandro Bernales',
#  'Sr. Karim Bianchi',
#  'Sr. Sergio Bobadilla',
#  'Sr. Gabriel Boric',
#  'Sr. Jorge Brito',
#  'Sr. Miguel Ángel Calisto',
#  'Sra. Karol Cariola',
#  'Sr. Álvaro Carter',
#  'Sra. Loreto Carvajal',
#  'Sra. Natalia Castillo',
#  'Sr. José Miguel Castro',
#  'Sr. Juan Luis Castro',
#  'Sr. Ricardo Celis',
#  'Sr. Andrés Celis',
#  'Sra. Daniella Cicardini',
#  'Sra. Sofía Cid',
#  'Sr. Juan Antonio Coloma',
#  'Sr. Miguel Crispi',
#  'Sr. Luciano Cruz-Coke',
#  'Sra. Catalina Del Real',
#  'Sr. Mario Desbordes',
#  'Sr. Marcelo Díaz',
#  'Sr. Jorge Durán',
#  'Sr. Eduardo Durán',
# ...

# %%
partidos
# Out:
# ['Partido: PH',
#  'Partido: UDI',
#  'Partido: IND',
#  'Partido: EVOP',
#  'Partido: PS',
#  'Partido: UDI',
#  'Partido: UDI',
#  'Partido: DC',
#  'Partido: IND',
#  'Partido: UDI',
#  'Partido: PC',
#  'Partido: UDI',
#  'Partido: UDI',
#  'Partido: RN',
#  'Partido: LIBERAL',
#  'Partido: IND',
#  'Partido: UDI',
#  'Partido: PCS',
#  'Partido: RD',
#  'Partido: DC',
#  'Partido: PC',
#  'Partido: UDI',
#  'Partido: PPD',
#  'Partido: RD',
#  'Partido: RN',
#  'Partido: PS',
#  'Partido: PPD',
#  'Partido: RN',
#  'Partido: PS',
#  'Partido: RN',
#  'Partido: UDI',
#  'Partido: RD',
#  'Partido: EVOP',
#  'Partido: RN',
#  'Partido: RN',
#  'Partido: IND',
#  'Partido: RN',
#  'Partido: RN',
#  'Partido: RN',
#  'Partido: PS',
#  'Partido: PS',
#  'Partido: DC',
#  'Partido: RN',
#  'Partido: UDI',
#  'Partido: RN',
#  'Partido: UDI',
#  'Partido: RN',
#  'Partido: RN',
#  'Partido: IND',
#  'Partido: PPD',
#  'Partido: PEV',
#  'Partido: PPD',
#  'Partido: PC',
# ...

# %%
import pandas as pd
df = pd.DataFrame(list(zip(senadores, partidos)), 
               columns =['senador', 'partido']) 
df.head()
# Out:
#                  senador        partido
# 0   Sr. Florcita Alarcón    Partido: PH
# 1   Sr. Jorge Alessandri   Partido: UDI
# 2        Sr. René Alinco   Partido: IND
# 3  Sr. Sebastián Álvarez  Partido: EVOP
# 4     Sra. Jenny Álvarez    Partido: PS

# %%
df.to_csv('senadores.csv')
